# %%
import pandas as pd

data = pd.read_csv("data/menus_cleaned.csv")
data.head()
# Out:
#          restaurant        city menu_type  category                dish  \
# 0  Jack and Jacky's  Leeuwarden     Lunch     Bowls           AÇAI BOWL
# 1  Jack and Jacky's  Leeuwarden     Lunch     Bowls     CHEESECAKE OATS
# 2  Jack and Jacky's  Leeuwarden     Lunch     Bowls  MANGO MADNESS BOWL
# 3  Jack and Jacky's  Leeuwarden     Lunch     Bowls      BREAKFAST BOWL
# 4  Jack and Jacky's  Leeuwarden     Lunch  Pancakes      BERRY PANCAKES
#
#    price                                        description        tags
# 0   13.2  Açai, banaan, kokosdrink, granola, pindaswirl,...         NaN
# 1   10.8  Overnight oats, Griekse yoghurt, aardbeienpure...  vegetarian
# 2   11.6  Mango, banaan, kokosdrink, aardbei, granola, h...  vegetarian
# 3   10.1  Griekse yoghurt, granola, banaan, chiazaad, bl...  vegetarian
# 4   14.6  Bananen pannenkoekjes, Griekse yoghurtroom, ba...  vegetarian

# %%
data.shape
# Out:
# (641, 8)

# %%
# Checking for nan values
data.isna().sum()
# Out:
# restaurant       0
# city             0
# menu_type        0
# category         0
# dish             0
# price            0
# description    105
# tags           171
# dtype: int64

# %%
# Selecting only the rows with as category Salads
salads = data[data["category"] == "Salads"]
salads.head(20)
# Out:
#           restaurant        city menu_type category                dish  \
# 16  Jack and Jacky's  Leeuwarden     Lunch   Salads             CHICKEN
# 17  Jack and Jacky's  Leeuwarden     Lunch   Salads              SALMON
# 18  Jack and Jacky's  Leeuwarden     Lunch   Salads             BURRATA
# 19  Jack and Jacky's  Leeuwarden     Lunch   Salads           CARPACCIO
# 20  Jack and Jacky's  Leeuwarden     Lunch   Salads             EXTRA'S
# 21  Jack and Jacky's  Leeuwarden     Lunch   Salads              KOFFIE
# 22  Jack and Jacky's  Leeuwarden     Lunch   Salads           AMERICANO
# 23  Jack and Jacky's  Leeuwarden     Lunch   Salads            ESPRESSO
# 24  Jack and Jacky's  Leeuwarden     Lunch   Salads     DOUBLE ESPRESSO
# 25  Jack and Jacky's  Leeuwarden     Lunch   Salads  ESPRESSO MACCHIATO
# 26  Jack and Jacky's  Leeuwarden     Lunch   Salads          CAPPUCCINO
# 27  Jack and Jacky's  Leeuwarden     Lunch   Salads             CORTADO
# ...
